# %% [markdown]
# # Deploy Trained Smolvla Policy
#
# <img src="./media/rollout3.gif" width="480" height="360">
#
# Deploy trained policy in simulation.

# %%
# !pip install transformers==4.50.3
# !pip install num2words
# !pip install accelerate
# !pip install safetensors>=0.4.3
# Out:
# Requirement already satisfied: transformers==4.50.3 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (4.50.3)
# Requirement already satisfied: filelock in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from transformers==4.50.3) (3.25.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from transformers==4.50.3) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from transformers==4.50.3) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from transformers==4.50.3) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from transformers==4.50.3) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from transformers==4.50.3) (2026.2.28)
# Requirement already satisfied: requests in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from transformers==4.50.3) (2.32.5)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from transformers==4.50.3) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from transformers==4.50.3) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from transformers==4.50.3) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.26.0->transformers==4.50.3) (2024.12.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.26.0->transformers==4.50.3) (1.4.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.26.0->transformers==4.50.3) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from requests->transformers==4.50.3) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from requests->transformers==4.50.3) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from requests->transformers==4.50.3) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from requests->transformers==4.50.3) (2026.2.25)
# Collecting num2words
#   Using cached num2words-0.5.14-py3-none-any.whl.metadata (13 kB)
# Collecting docopt>=0.6.2 (from num2words)
#   Using cached docopt-0.6.2-py2.py3-none-any.whl
# Using cached num2words-0.5.14-py3-none-any.whl (163 kB)
# Installing collected packages: docopt, num2words
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [num2words]
# Successfully installed docopt-0.6.2 num2words-0.5.14
# Collecting accelerate
#   Using cached accelerate-1.13.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.17 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from accelerate) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from accelerate) (25.0)
# Requirement already satisfied: psutil in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from accelerate) (7.2.2)
# Requirement already satisfied: pyyaml in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from accelerate) (6.0.3)
# Requirement already satisfied: torch>=2.0.0 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from accelerate) (2.6.0)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from accelerate) (0.36.2)
# Requirement already satisfied: safetensors>=0.4.3 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from accelerate) (0.5.3)
# Requirement already satisfied: filelock in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from huggingface_hub>=0.21.0->accelerate) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from huggingface_hub>=0.21.0->accelerate) (2024.12.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from huggingface_hub>=0.21.0->accelerate) (1.4.2)
# Requirement already satisfied: requests in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from huggingface_hub>=0.21.0->accelerate) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from huggingface_hub>=0.21.0->accelerate) (4.67.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from huggingface_hub>=0.21.0->accelerate) (4.15.0)
# Requirement already satisfied: networkx in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kevin/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2026.2.25)
# Using cached accelerate-1.13.0-py3-none-any.whl (383 kB)
# Installing collected packages: accelerate
# Successfully installed accelerate-1.13.0

# %% [markdown]
# ### [Optional] Download Dataset

# %%
'''
If you want to use the collected dataset, please download it from Hugging Face.
'''
# !git clone https://huggingface.co/datasets/Jeongeun/omy_pnp_language

# %% [markdown]
# ## Step 2. Train Model

# %%
# !python train_model.py --config_path smolvla_omy.yaml

# %% [markdown]
# ## Step 3. Deploy

# %%
from lerobot.common.datasets.lerobot_dataset import LeRobotDataset, LeRobotDatasetMetadata
import numpy as np
from lerobot.common.datasets.utils import write_json, serialize_dict
from lerobot.common.policies.smolvla.configuration_smolvla import SmolVLAConfig
from lerobot.common.policies.smolvla.modeling_smolvla import SmolVLAPolicy
from lerobot.configs.types import FeatureType
from lerobot.common.datasets.factory import resolve_delta_timestamps
from lerobot.common.datasets.utils import dataset_to_policy_features
import torch
from PIL import Image
import torchvision

# %%
device = 'cuda'

# %%
try:
    dataset_metadata = LeRobotDatasetMetadata("omy_pnp_language", root='./demo_data_example')
except:
    dataset_metadata = LeRobotDatasetMetadata("omy_pnp_language", root='./omy_pnp_language')
features = dataset_to_policy_features(dataset_metadata.features)
output_features = {key: ft for key, ft in features.items() if ft.type is FeatureType.ACTION}
input_features = {key: ft for key, ft in features.items() if key not in output_features}
# Policies are initialized with a configuration class, in this case `DiffusionConfig`. For this example,
# we'll just use the defaults and so no arguments other than input/output features need to be passed.
# Temporal ensemble to make smoother trajectory predictions
cfg = SmolVLAConfig(input_features=input_features, output_features=output_features, chunk_size= 5, n_action_steps=5)
delta_timestamps = resolve_delta_timestamps(cfg, dataset_metadata)
# Out:
# WARNING:root:Device 'None' is not available. Switching to 'cuda'.

# %%
# We can now instantiate our policy with this config and the dataset stats.
# policy = SmolVLAPolicy.from_pretrained('./ckpt/smolvla_omy/checkpoints/last/pretrained_model', dataset_stats=dataset_metadata.stats)
# You can load the trained policy from hub if you don't have the resources to train it.
policy = SmolVLAPolicy.from_pretrained("Jeongeun/omy_pnp_smolvla", config=cfg, dataset_stats=dataset_metadata.stats)
policy.to(device)
# Out:
# Reducing the number of VLM layers to 16 ...
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[8], line 4
#       1 # We can now instantiate our policy with this config and the dataset stats.
#       2 # policy = SmolVLAPolicy.from_pretrained('./ckpt/smolvla_omy/checkpoints/last/pretrained_model', dataset_stats=dataset_metadata.stats)
#       3 # You can load the trained policy from hub if you don't have the resources to train it.
# ----> 4 policy = SmolVLAPolicy.from_pretrained("Jeongeun/omy_pnp_pi0", config=cfg, dataset_stats=dataset_metadata.stats)
#       5 policy.to(device)
#
# File ~/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages/lerobot/common/policies/pretrained.py:127, in PreTrainedPolicy.from_pretrained(cls, pretrained_name_or_path, config, force_download, resume_download, proxies, token, cache_dir, local_files_only, revision, strict, **kwargs)
#     115 try:
#     116     model_file = hf_hub_download(
#     117         repo_id=model_id,
#     118         filename=SAFETENSORS_SINGLE_FILE,
#    (...)
#     125         local_files_only=local_files_only,
#     126     )
# --> 127     policy = cls._load_as_safetensor(instance, model_file, config.device, strict)
#     128 except HfHubHTTPError as e:
#     129     raise FileNotFoundError(
#     130         f"{SAFETENSORS_SINGLE_FILE} not found on the HuggingFace Hub in {model_id}"
#     131     ) from e
#
# File ~/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages/lerobot/common/policies/pretrained.py:150, in PreTrainedPolicy._load_as_safetensor(cls, model, model_file, map_location, strict)
#     148         model.to(map_location)
#     149 else:
# --> 150     safetensors.torch.load_model(model, model_file, strict=strict, device=map_location)
#     151 return model
#
# File ~/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages/safetensors/torch.py:202, in load_model(model, filename, strict, device)
#     176 def load_model(
#     177     model: torch.nn.Module, filename: Union[str, os.PathLike], strict: bool = True, device: Union[str, int] = "cpu"
#     178 ) -> Tuple[List[str], List[str]]:
#     179     """
#     180     Loads a given filename onto a torch model.
#     181     This method exists specifically to avoid tensor sharing issues which are
#    (...)
#     200             the load.
#     201     """
# --> 202     state_dict = load_file(filename, device=device)
#     203     model_state_dict = model.state_dict()
#     204     to_removes = _remove_duplicate_names(model_state_dict, preferred_names=state_dict.keys())
#
# File ~/miniconda3/envs/lerobot-mujoco-tutorial/lib/python3.10/site-packages/safetensors/torch.py:315, in load_file(filename, device)
#     313 with safe_open(filename, framework="pt", device=device) as f:
#     314     for k in f.keys():
# --> 315         result[k] = f.get_tensor(k)
#     316 return result
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 64.00 MiB. GPU 0 has a total capacity of 5.61 GiB of which 42.31 MiB is free. Including non-PyTorch memory, this process has 5.57 GiB memory in use. Of the allocated memory 5.43 GiB is allocated by PyTorch, and 72.55 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
from mujoco_env.y_env2 import SimpleEnv2
xml_path = './asset/example_scene_y2.xml'
PnPEnv = SimpleEnv2(xml_path, action_type='joint_angle')
# Out:
# -----------------------------------------------------------------------------
# name:[Tabletop] dt:[0.002] HZ:[500]
#  n_qpos:[31] n_qvel:[28] n_qacc:[28] n_ctrl:[10]
#  integrator:[IMPLICITFAST]
#
# n_body:[23]
#  [0/23] [world] mass:[0.00]kg
#  [1/23] [front_object_table] mass:[1.00]kg
#  [2/23] [camera] mass:[0.00]kg
#  [3/23] [camera2] mass:[0.00]kg
#  [4/23] [camera3] mass:[0.00]kg
#  [5/23] [link1] mass:[2.06]kg
#  [6/23] [link2] mass:[3.68]kg
#  [7/23] [link3] mass:[2.39]kg
#  [8/23] [link4] mass:[1.40]kg
#  [9/23] [link5] mass:[1.40]kg
#  [10/23] [link6] mass:[0.65]kg
#  [11/23] [camera_center] mass:[0.00]kg
#  [12/23] [tcp_link] mass:[0.32]kg
#  [13/23] [rh_p12_rn_r1] mass:[0.07]kg
#  [14/23] [rh_p12_rn_r2] mass:[0.02]kg
#  [15/23] [rh_p12_rn_l1] mass:[0.07]kg
#  [16/23] [rh_p12_rn_l2] mass:[0.02]kg
#  [17/23] [body_obj_mug_5] mass:[0.00]kg
#  [18/23] [object_mug_5] mass:[0.08]kg
#  [19/23] [body_obj_plate_11] mass:[0.00]kg
#  [20/23] [object_plate_11] mass:[0.10]kg
#  [21/23] [body_obj_mug_6] mass:[0.00]kg
#  [22/23] [object_mug_6] mass:[0.08]kg
# body_total_mass:[13.35]kg
#
# n_geom:[116]
# geom_names:['floor', None, 'front_object_table', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
#
# n_mesh:[112]
# mesh_names:['base_unit', 'link1', 'link2', 'link3', 'link4', 'link5', 'link6', 'flange', 'base', 'r1', 'r2', 'l1', 'l2', 'mug_5_normalized_0_vis', 'mug_5_normalized_collision_22._coll', 'mug_5_normalized_collision_23._coll', 'mug_5_normalized_collision_21._coll', 'mug_5_normalized_collision_20._coll', 'mug_5_normalized_collision_24._coll', 'mug_5_normalized_collision_30._coll', 'mug_5_normalized_collision_18._coll', 'mug_5_normalized_collision_19._coll', 'mug_5_normalized_collision_31._coll', 'mug_5_normalized_collision_25._coll', 'mug_5_normalized_collision_27._coll', 'mug_5_normalized_collision_26._coll', 'mug_5_normalized_collision_9._coll', 'mug_5_normalized_collision_8._coll', 'mug_5_normalized_collision_6._coll', 'mug_5_normalized_collision_7._coll', 'mug_5_normalized_collision_5._coll', 'mug_5_normalized_collision_4._coll', 'mug_5_normalized_collision_0._coll', 'mug_5_normalized_collision_1._coll', 'mug_5_normalized_collision_3._coll', 'mug_5_normalized_collision_2._coll', 'mug_5_normalized_collision_17._coll', 'mug_5_normalized_collision_16._coll', 'mug_5_normalized_collision_28._coll', 'mug_5_normalized_collision_14._coll', 'mug_5_normalized_collision_15._coll', 'mug_5_normalized_collision_29._coll', 'mug_5_normalized_collision_11._coll', 'mug_5_normalized_collision_10._coll', 'mug_5_normalized_collision_12._coll', 'mug_5_normalized_collision_13._coll', 'plate_11_normalized_0_vis', 'plate_11_normalized_collision_22._coll', 'plate_11_normalized_collision_23._coll', 'plate_11_normalized_collision_21._coll', 'plate_11_normalized_collision_20._coll', 'plate_11_normalized_collision_24._coll', 'plate_11_normalized_collision_30._coll', 'plate_11_normalized_collision_18._coll', 'plate_11_normalized_collision_19._coll', 'plate_11_normalized_collision_31._coll', 'plate_11_normalized_collision_25._coll', 'plate_11_normalized_collision_27._coll', 'plate_11_normalized_collision_26._coll', 'plate_11_normalized_collision_9._coll', 'plate_11_normalized_collision_8._coll', 'plate_11_normalized_collision_6._coll', 'plate_11_normalized_collision_7._coll', 'plate_11_normalized_collision_5._coll', 'plate_11_normalized_collision_4._coll', 'plate_11_normalized_collision_0._coll', 'plate_11_normalized_collision_1._coll', 'plate_11_normalized_collision_3._coll', 'plate_11_normalized_collision_2._coll', 'plate_11_normalized_collision_17._coll', 'plate_11_normalized_collision_16._coll', 'plate_11_normalized_collision_28._coll', 'plate_11_normalized_collision_14._coll', 'plate_11_normalized_collision_15._coll', 'plate_11_normalized_collision_29._coll', 'plate_11_normalized_collision_11._coll', 'plate_11_normalized_collision_10._coll', 'plate_11_normalized_collision_12._coll', 'plate_11_normalized_collision_13._coll', 'mug_6_normalized_0_vis', 'mug_6_normalized_collision_22._coll', 'mug_6_normalized_collision_23._coll', 'mug_6_normalized_collision_21._coll', 'mug_6_normalized_collision_20._coll', 'mug_6_normalized_collision_24._coll', 'mug_6_normalized_collision_30._coll', 'mug_6_normalized_collision_18._coll', 'mug_6_normalized_collision_19._coll', 'mug_6_normalized_collision_31._coll', 'mug_6_normalized_collision_25._coll', 'mug_6_normalized_collision_27._coll', 'mug_6_normalized_collision_26._coll', 'mug_6_normalized_collision_9._coll', 'mug_6_normalized_collision_8._coll', 'mug_6_normalized_collision_6._coll', 'mug_6_normalized_collision_7._coll', 'mug_6_normalized_collision_5._coll', 'mug_6_normalized_collision_4._coll', 'mug_6_normalized_collision_0._coll', 'mug_6_normalized_collision_1._coll', 'mug_6_normalized_collision_3._coll', 'mug_6_normalized_collision_2._coll', 'mug_6_normalized_collision_17._coll', 'mug_6_normalized_collision_16._coll', 'mug_6_normalized_collision_28._coll', 'mug_6_normalized_collision_14._coll', 'mug_6_normalized_collision_15._coll', 'mug_6_normalized_collision_29._coll', 'mug_6_normalized_collision_11._coll', 'mug_6_normalized_collision_10._coll', 'mug_6_normalized_collision_12._coll', 'mug_6_normalized_collision ...
#
# n_joint:[13]
#  [0/13] [joint1] axis:[0. 0. 1.]
#  [1/13] [joint2] axis:[0. 1. 0.]
#  [2/13] [joint3] axis:[0. 1. 0.]
#  [3/13] [joint4] axis:[0. 1. 0.]
#  [4/13] [joint5] axis:[0. 0. 1.]
#  [5/13] [joint6] axis:[0. 1. 0.]
#  [6/13] [rh_r1] axis:[1. 0. 0.]
#  [7/13] [rh_r2] axis:[-1.  0.  0.]
#  [8/13] [rh_l1] axis:[-1.  0.  0.]
#  [9/13] [rh_l2] axis:[1. 0. 0.]
#  [10/13] [None] axis:[0. 0. 1.]
#  [11/13] [None] axis:[0. 0. 1.]
#  [12/13] [None] axis:[0. 0. 1.]
#
# n_dof:[28] (=number of rows of Jacobian)
#  [0/28] [None] attached joint:[joint1] body:[link1]
#  [1/28] [None] attached joint:[joint2] body:[link2]
#  [2/28] [None] attached joint:[joint3] body:[link3]
#  [3/28] [None] attached joint:[joint4] body:[link4]
#  [4/28] [None] attached joint:[joint5] body:[link5]
#  [5/28] [None] attached joint:[joint6] body:[link6]
#  [6/28] [None] attached joint:[rh_r1] body:[rh_p12_rn_r1]
#  [7/28] [None] attached joint:[rh_r2] body:[rh_p12_rn_r2]
#  [8/28] [None] attached joint:[rh_l1] body:[rh_p12_rn_l1]
#  [9/28] [None] attached joint:[rh_l2] body:[rh_p12_rn_l2]
#  [10/28] [None] attached joint:[None] body:[body_obj_mug_5]
#  [11/28] [None] attached joint:[None] body:[body_obj_mug_5]
#  [12/28] [None] attached joint:[None] body:[body_obj_mug_5]
#  [13/28] [None] attached joint:[None] body:[body_obj_mug_5]
#  [14/28] [None] attached joint:[None] body:[body_obj_mug_5]
#  [15/28] [None] attached joint:[None] body:[body_obj_mug_5]
#  [16/28] [None] attached joint:[None] body:[body_obj_plate_11]
#  [17/28] [None] attached joint:[None] body:[body_obj_plate_11]
#  [18/28] [None] attached joint:[None] body:[body_obj_plate_11]
#  [19/28] [None] attached joint:[None] body:[body_obj_plate_11]
#  [20/28] [None] attached joint:[None] body:[body_obj_plate_11]
#  [21/28] [None] attached joint:[None] body:[body_obj_plate_11]
#  [22/28] [None] attached joint:[None] body:[body_obj_mug_6]
#  [23/28] [None] attached joint:[None] body:[body_obj_mug_6]
#  [24/28] [None] attached joint:[None] body:[body_obj_mug_6]
#  [25/28] [None] attached joint:[None] body:[body_obj_mug_6]
#  [26/28] [None] attached joint:[None] body:[body_obj_mug_6]
#  [27/28] [None] attached joint:[None] body:[body_obj_mug_6]
#
# Free joint information. n_free_joint:[3]
#  [0/3] [None] body_name_attached:[body_obj_mug_5]
#  [1/3] [None] body_name_attached:[body_obj_plate_11]
#  [2/3] [None] body_name_attached:[body_obj_mug_6]
#
# Revolute joint information. n_rev_joint:[10]
#  [0/10] [joint1] range:[-6.283]~[6.283]
#  [1/10] [joint2] range:[-6.283]~[6.283]
#  [2/10] [joint3] range:[-6.283]~[6.283]
#  [3/10] [joint4] range:[-6.283]~[6.283]
#  [4/10] [joint5] range:[-6.283]~[6.283]
#  [5/10] [joint6] range:[-6.283]~[6.283]
#  [6/10] [rh_r1] range:[0.000]~[1.100]
#  [7/10] [rh_r2] range:[0.000]~[1.000]
#  [8/10] [rh_l1] range:[0.000]~[1.100]
#  [9/10] [rh_l2] range:[0.000]~[1.000]
#
# Prismatic joint information. n_pri_joint:[0]
#
# Control information. n_ctrl:[10]
#  [0/10] [actuator_joint1] range:[-6.283]~[6.283] gear:[1.00] type:[JOINT]
#  [1/10] [actuator_joint2] range:[-6.283]~[6.283] gear:[1.00] type:[JOINT]
#  [2/10] [actuator_joint3] range:[-6.283]~[6.283] gear:[1.00] type:[JOINT]
#  [3/10] [actuator_joint4] range:[-6.283]~[6.283] gear:[1.00] type:[JOINT]
#  [4/10] [actuator_joint5] range:[-6.283]~[6.283] gear:[1.00] type:[JOINT]
#  [5/10] [actuator_joint6] range:[-6.283]~[6.283] gear:[1.00] type:[JOINT]
#  [6/10] [actuator_rh_r1] range:[0.000]~[1.100] gear:[1.00] type:[JOINT]
#  [7/10] [actuator_rh_r2] range:[0.000]~[1.000] gear:[1.00] type:[JOINT]
#  [8/10] [actuator_rh_l1] range:[0.000]~[1.100] gear:[1.00] type:[JOINT]
#  [9/10] [actuator_rh_l2] range:[0.000]~[1.000] gear:[1.00] type:[JOINT]
#
# Camera information. n_cam:[4]
#  [0/4] [agentview] fov:[60.0]
#  [1/4] [topview] fov:[90.0]
#  [2/4] [sideview] fov:[90.0]
#  [3/4] [egocentric] fov:[90.0]
#
# n_sensor:[0]
# sensor_names:[]
# n_site:[9]
# site_names:['bottom_site_mug_5', 'top_site_mug_5', 'horizontal_radius_site_mug_5', 'bottom_site_plate_11', 'top_site_plate_11', 'horizontal_radius_site_plate_11', 'bottom_site_mug_6', 'top_site_mug_6', 'horizontal_radius_site_mug_6']
# -----------------------------------------------------------------------------
# env:[Tabletop] reset
# env:[Tabletop] reset
# env:[Tabletop] initalize viewer
# DONE INITIALIZATION

# %%
from torchvision import transforms
# Approach 1: Using torchvision.transforms
def get_default_transform(image_size: int = 224):
    """
    Returns a torchvision transform that:
     Converts to a FloatTensor and scales pixel values [0,255] -> [0.0,1.0]
    """
    return transforms.Compose([
        transforms.ToTensor(),  # PIL [0–255] -> FloatTensor [0.0–1.0], shape C×H×W
    ])

# %%
step = 0
PnPEnv.reset(seed=0)
policy.reset()
policy.eval()
save_image = True
IMG_TRANSFORM = get_default_transform()
while PnPEnv.env.is_viewer_alive():
    PnPEnv.step_env()
    if PnPEnv.env.loop_every(HZ=20):
        # Check if the task is completed
        success = PnPEnv.check_success()
        if success:
            print('Success')
            # Reset the environment and action queue
            policy.reset()
            PnPEnv.reset()
            step = 0
            save_image = False
        # Get the current state of the environment
        state = PnPEnv.get_joint_state()[:6]
        # Get the current image from the environment
        image, wirst_image = PnPEnv.grab_image()
        image = Image.fromarray(image)
        image = image.resize((256, 256))
        image = IMG_TRANSFORM(image)
        wrist_image = Image.fromarray(wirst_image)
        wrist_image = wrist_image.resize((256, 256))
        wrist_image = IMG_TRANSFORM(wrist_image)
        data = {
            'observation.state': torch.tensor([state]).to(device),
            'observation.image': image.unsqueeze(0).to(device),
            'observation.wrist_image': wrist_image.unsqueeze(0).to(device),
            'task': [PnPEnv.instruction],
        }
        # Select an action
        action = policy.select_action(data)
        action = action[0,:7].cpu().detach().numpy()
        # Take a step in the environment
        _ = PnPEnv.step(action)
        PnPEnv.render()
        step += 1
        success = PnPEnv.check_success()
        if success:
            print('Success')
            break
# Out:
# DONE INITIALIZATION
# /tmp/ipykernel_3326535/3859105902.py:30: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:254.)
#   'observation.state': torch.tensor([state]).to(device),
# Success
# DONE INITIALIZATION
# Success
# DONE INITIALIZATION

# %%
# policy.push_to_hub(
#     repo_id='Jeongeun/omy_pnp_smolvla',
#     commit_message='Add trained policy for PnP task',
# )
# Out:
# model.safetensors: 100%|██████████| 1.20G/1.20G [02:26<00:00, 8.19MB/s]
# CommitInfo(commit_url='https://huggingface.co/Jeongeun/omy_pnp_smolvla/commit/738e2cb9235562d58842ceb8a9469ae21278bb53', commit_message='Add trained policy for PnP task', commit_description='', oid='738e2cb9235562d58842ceb8a9469ae21278bb53', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Jeongeun/omy_pnp_smolvla', endpoint='https://huggingface.co', repo_type='model', repo_id='Jeongeun/omy_pnp_smolvla'), pr_revision=None, pr_num=None)
